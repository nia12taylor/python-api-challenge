# %% [markdown]
# # WeatherPy
#
# ---

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 588

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?appid="+weather_api_key+"&units=metric&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url+city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        response = requests.get(city_url).json()
        #print(response)
        # Parse the JSON and retrieve data
        city_weather = response['weather'][0]['main']

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response['coord']['lat']
        city_lng = response['coord']['lon']
        city_max_temp = response['main']['temp_max']
        city_humidity = response['main']['humidity']
        city_clouds = response['clouds']['all']
        city_wind = response['wind']['speed']
        city_country = response['sys']['country']
        city_date = response['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | aykhal
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | rantepao
# Processing Record 9 of Set 1 | lavrentiya
# Processing Record 10 of Set 1 | adre
# Processing Record 11 of Set 1 | port hardy
# Processing Record 12 of Set 1 | san andres
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 1 | yumen
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | mbala
# Processing Record 22 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 1 | lompoc
# Processing Record 24 of Set 1 | taganak
# Processing Record 25 of Set 1 | tuktoyaktuk
# Processing Record 26 of Set 1 | westport
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | zhigansk
# Processing Record 29 of Set 1 | nanortalik
# Processing Record 30 of Set 1 | airai
# Processing Record 31 of Set 1 | tubruq
# City not found. Skipping...
# Processing Record 32 of Set 1 | buchanan
# Processing Record 33 of Set 1 | ballina
# Processing Record 34 of Set 1 | teterow
# Processing Record 35 of Set 1 | saskylakh
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 38 of Set 1 | brae
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | te anau
# Processing Record 41 of Set 1 | vilhena
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | la tuque
# Processing Record 44 of Set 1 | kumluca
# Processing Record 45 of Set 1 | saint-pierre
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | port lincoln
# Processing Record 50 of Set 1 | daloa
# Processing Record 0 of Set 2 | springbok
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | tasiilaq
# Processing Record 3 of Set 2 | souillac
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 2 | warwick
# Processing Record 7 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 8 of Set 2 | pafos
# Processing Record 9 of Set 2 | san quintin
# Processing Record 10 of Set 2 | tura
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | sur
# Processing Record 13 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 2 | lagoa
# Processing Record 15 of Set 2 | qaanaaq
# Processing Record 16 of Set 2 | tual
# Processing Record 17 of Set 2 | east london
# Processing Record 18 of Set 2 | north bend
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | fort nelson
# Processing Record 21 of Set 2 | wad rawah
# Processing Record 22 of Set 2 | keti bandar
# Processing Record 23 of Set 2 | poum
# Processing Record 24 of Set 2 | cherskiy
# Processing Record 25 of Set 2 | bambous virieux
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | mahebourg
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | southaven
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | el playon
# Processing Record 32 of Set 2 | agadez
# Processing Record 33 of Set 2 | bredy
# Processing Record 34 of Set 2 | vardo
# Processing Record 35 of Set 2 | ahipara
# Processing Record 36 of Set 2 | praya
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | guerrero negro
# Processing Record 39 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | ilulissat
# Processing Record 42 of Set 2 | inta
# Processing Record 43 of Set 2 | huarmey
# Processing Record 44 of Set 2 | okha
# Processing Record 45 of Set 2 | aasiaat
# Processing Record 46 of Set 2 | bardiyah
# Processing Record 47 of Set 2 | albany
# Processing Record 48 of Set 2 | yulara
# Processing Record 49 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 0 of Set 3 | calama
# Processing Record 1 of Set 3 | san-pedro
# Processing Record 2 of Set 3 | dingle
# Processing Record 3 of Set 3 | kruisfontein
# Processing Record 4 of Set 3 | kamenka
# Processing Record 5 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 6 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 3 | stuttgart
# Processing Record 9 of Set 3 | port-gentil
# Processing Record 10 of Set 3 | bengkulu
# Processing Record 11 of Set 3 | ancud
# Processing Record 12 of Set 3 | paamiut
# Processing Record 13 of Set 3 | ostrovnoy
# Processing Record 14 of Set 3 | comodoro rivadavia
# Processing Record 15 of Set 3 | wlingi
# Processing Record 16 of Set 3 | ayan
# Processing Record 17 of Set 3 | thompson
# Processing Record 18 of Set 3 | buala
# Processing Record 19 of Set 3 | kavieng
# Processing Record 20 of Set 3 | gat
# Processing Record 21 of Set 3 | umm lajj
# Processing Record 22 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 3 | capreol
# Processing Record 24 of Set 3 | kloulklubed
# Processing Record 25 of Set 3 | marienburg
# Processing Record 26 of Set 3 | disna
# Processing Record 27 of Set 3 | hambantota
# Processing Record 28 of Set 3 | yurimaguas
# Processing Record 29 of Set 3 | hamilton
# Processing Record 30 of Set 3 | richards bay
# Processing Record 31 of Set 3 | as
# City not found. Skipping...
# Processing Record 32 of Set 3 | severo-kurilsk
# Processing Record 33 of Set 3 | buzmeyin
# Processing Record 34 of Set 3 | kot khai
# Processing Record 35 of Set 3 | veinticinco de mayo
# Processing Record 36 of Set 3 | motril
# Processing Record 37 of Set 3 | barrow
# Processing Record 38 of Set 3 | iracoubo
# Processing Record 39 of Set 3 | kavaratti
# Processing Record 40 of Set 3 | trincomalee
# Processing Record 41 of Set 3 | puerto ayora
# Processing Record 42 of Set 3 | matagami
# Processing Record 43 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 3 | nikolskoye
# Processing Record 45 of Set 3 | namie
# Processing Record 46 of Set 3 | goma
# Processing Record 47 of Set 3 | hobyo
# Processing Record 48 of Set 3 | khatanga
# Processing Record 49 of Set 3 | mala
# Processing Record 0 of Set 4 | san patricio
# Processing Record 1 of Set 4 | yichang
# Processing Record 2 of Set 4 | saint-philippe
# Processing Record 3 of Set 4 | arraial do cabo
# Processing Record 4 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 4 | mezen
# Processing Record 6 of Set 4 | katsuura
# Processing Record 7 of Set 4 | vestmannaeyjar
# Processing Record 8 of Set 4 | aksaray
# Processing Record 9 of Set 4 | yinchuan
# Processing Record 10 of Set 4 | norman wells
# Processing Record 11 of Set 4 | hualmay
# Processing Record 12 of Set 4 | rovaniemi
# Processing Record 13 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 14 of Set 4 | baykit
# Processing Record 15 of Set 4 | kambove
# Processing Record 16 of Set 4 | vao
# Processing Record 17 of Set 4 | hovd
# Processing Record 18 of Set 4 | itoman
# Processing Record 19 of Set 4 | oldenburg
# Processing Record 20 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 4 | dharmanagar
# Processing Record 22 of Set 4 | cidreira
# Processing Record 23 of Set 4 | victoria
# Processing Record 24 of Set 4 | dikson
# Processing Record 25 of Set 4 | tromso
# Processing Record 26 of Set 4 | morristown
# Processing Record 27 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 28 of Set 4 | luderitz
# Processing Record 29 of Set 4 | belmonte
# Processing Record 30 of Set 4 | monroe
# Processing Record 31 of Set 4 | pangkalanbuun
# Processing Record 32 of Set 4 | peniche
# Processing Record 33 of Set 4 | kerur
# Processing Record 34 of Set 4 | saint-augustin
# Processing Record 35 of Set 4 | lebu
# Processing Record 36 of Set 4 | vanimo
# Processing Record 37 of Set 4 | isangel
# Processing Record 38 of Set 4 | saint george
# Processing Record 39 of Set 4 | jinka
# Processing Record 40 of Set 4 | morondava
# Processing Record 41 of Set 4 | hendijan
# City not found. Skipping...
# Processing Record 42 of Set 4 | jiroft
# City not found. Skipping...
# Processing Record 43 of Set 4 | karratha
# Processing Record 44 of Set 4 | xuddur
# Processing Record 45 of Set 4 | perth
# Processing Record 46 of Set 4 | srednekolymsk
# Processing Record 47 of Set 4 | katubao
# Processing Record 48 of Set 4 | chicama
# Processing Record 49 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 0 of Set 5 | kahului
# Processing Record 1 of Set 5 | severnoye
# Processing Record 2 of Set 5 | qui nhon
# Processing Record 3 of Set 5 | chokurdakh
# Processing Record 4 of Set 5 | port elizabeth
# Processing Record 5 of Set 5 | leningradskiy
# Processing Record 6 of Set 5 | beni mazar
# Processing Record 7 of Set 5 | upernavik
# Processing Record 8 of Set 5 | kodiak
# Processing Record 9 of Set 5 | salta
# Processing Record 10 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 5 | lasa
# Processing Record 12 of Set 5 | faya
# Processing Record 13 of Set 5 | kudahuvadhoo
# Processing Record 14 of Set 5 | nyrob
# Processing Record 15 of Set 5 | biak
# Processing Record 16 of Set 5 | savannah bight
# Processing Record 17 of Set 5 | carutapera
# Processing Record 18 of Set 5 | nelson bay
# Processing Record 19 of Set 5 | upington
# Processing Record 20 of Set 5 | korla
# Processing Record 21 of Set 5 | asfi
# Processing Record 22 of Set 5 | moiyabana
# City not found. Skipping...
# Processing Record 23 of Set 5 | unai
# Processing Record 24 of Set 5 | san rafael del sur
# Processing Record 25 of Set 5 | atasu
# Processing Record 26 of Set 5 | narsaq
# Processing Record 27 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 5 | aklavik
# Processing Record 29 of Set 5 | gizo
# Processing Record 30 of Set 5 | saint-joseph
# Processing Record 31 of Set 5 | telfs
# Processing Record 32 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 5 | orlik
# Processing Record 34 of Set 5 | sao filipe
# Processing Record 35 of Set 5 | iqaluit
# Processing Record 36 of Set 5 | nordlingen
# City not found. Skipping...
# Processing Record 37 of Set 5 | yandoon
# City not found. Skipping...
# Processing Record 38 of Set 5 | coihaique
# Processing Record 39 of Set 5 | constitucion
# Processing Record 40 of Set 5 | nouadhibou
# Processing Record 41 of Set 5 | makurdi
# Processing Record 42 of Set 5 | zhob
# Processing Record 43 of Set 5 | recke
# Processing Record 44 of Set 5 | aguachica
# Processing Record 45 of Set 5 | peyima
# Processing Record 46 of Set 5 | fairbanks
# Processing Record 47 of Set 5 | kandrian
# Processing Record 48 of Set 5 | anadyr
# Processing Record 49 of Set 5 | krasnyy chikoy
# Processing Record 0 of Set 6 | samarai
# Processing Record 1 of Set 6 | ribeira grande
# Processing Record 2 of Set 6 | port augusta
# Processing Record 3 of Set 6 | garbolovo
# Processing Record 4 of Set 6 | san carlos de bariloche
# Processing Record 5 of Set 6 | young
# Processing Record 6 of Set 6 | quatre cocos
# Processing Record 7 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 6 | sanica
# Processing Record 9 of Set 6 | yerbogachen
# Processing Record 10 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 6 | kyra
# Processing Record 12 of Set 6 | dunmore east
# Processing Record 13 of Set 6 | roald
# Processing Record 14 of Set 6 | clarence town
# Processing Record 15 of Set 6 | juelsminde
# Processing Record 16 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 6 | manokwari
# Processing Record 18 of Set 6 | meulaboh
# Processing Record 19 of Set 6 | laguna
# Processing Record 20 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 21 of Set 6 | nome
# Processing Record 22 of Set 6 | balykshi
# Processing Record 23 of Set 6 | deputatskiy
# Processing Record 24 of Set 6 | blagoveshchenka
# Processing Record 25 of Set 6 | vila franca do campo
# Processing Record 26 of Set 6 | ordzhonikidze
# Processing Record 27 of Set 6 | yar-sale
# Processing Record 28 of Set 6 | goderich
# Processing Record 29 of Set 6 | carnarvon
# Processing Record 30 of Set 6 | clyde river
# Processing Record 31 of Set 6 | turukhansk
# Processing Record 32 of Set 6 | gornopravdinsk
# Processing Record 33 of Set 6 | bagdarin
# Processing Record 34 of Set 6 | asosa
# Processing Record 35 of Set 6 | hwange
# Processing Record 36 of Set 6 | labuhan
# Processing Record 37 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 38 of Set 6 | constanza
# Processing Record 39 of Set 6 | porto novo
# Processing Record 40 of Set 6 | saiha
# Processing Record 41 of Set 6 | los llanos de aridane
# Processing Record 42 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 6 | homer
# Processing Record 44 of Set 6 | conde
# Processing Record 45 of Set 6 | pingzhuang
# Processing Record 46 of Set 6 | sorland
# Processing Record 47 of Set 6 | allapalli
# Processing Record 48 of Set 6 | bilma
# Processing Record 49 of Set 6 | humaita
# Processing Record 0 of Set 7 | eskilstuna
# Processing Record 1 of Set 7 | ketchikan
# Processing Record 2 of Set 7 | geraldton
# Processing Record 3 of Set 7 | longyearbyen
# Processing Record 4 of Set 7 | milingimbi
# City not found. Skipping...
# Processing Record 5 of Set 7 | college
# Processing Record 6 of Set 7 | road town
# Processing Record 7 of Set 7 | virginia beach
# Processing Record 8 of Set 7 | anshun
# Processing Record 9 of Set 7 | ngorongoro
# Processing Record 10 of Set 7 | ardahan
# Processing Record 11 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 7 | paulesti
# Processing Record 13 of Set 7 | yelizovo
# Processing Record 14 of Set 7 | lata
# Processing Record 15 of Set 7 | pisco
# Processing Record 16 of Set 7 | naples
# Processing Record 17 of Set 7 | cam ranh
# Processing Record 18 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 19 of Set 7 | ariquemes
# Processing Record 20 of Set 7 | beringovskiy
# Processing Record 21 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 7 | provideniya
# Processing Record 23 of Set 7 | ponta do sol
# Processing Record 24 of Set 7 | tautira
# Processing Record 25 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 26 of Set 7 | dauphin
# Processing Record 27 of Set 7 | oriximina
# Processing Record 28 of Set 7 | cristalina
# Processing Record 29 of Set 7 | mount gambier
# Processing Record 30 of Set 7 | yurino
# Processing Record 31 of Set 7 | namatanai
# Processing Record 32 of Set 7 | gien
# Processing Record 33 of Set 7 | lamar
# Processing Record 34 of Set 7 | nivala
# Processing Record 35 of Set 7 | gravdal
# Processing Record 36 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 7 | quelimane
# Processing Record 38 of Set 7 | pangnirtung
# Processing Record 39 of Set 7 | juneau
# Processing Record 40 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 7 | touros
# Processing Record 42 of Set 7 | nikel
# Processing Record 43 of Set 7 | providencia
# Processing Record 44 of Set 7 | morshansk
# Processing Record 45 of Set 7 | kneza
# City not found. Skipping...
# Processing Record 46 of Set 7 | tomatlan
# Processing Record 47 of Set 7 | vaitape
# Processing Record 48 of Set 7 | mesaria
# Processing Record 49 of Set 7 | torbay
# Processing Record 0 of Set 8 | tocopilla
# Processing Record 1 of Set 8 | codrington
# Processing Record 2 of Set 8 | juegang
# Processing Record 3 of Set 8 | paskov
# Processing Record 4 of Set 8 | burnie
# Processing Record 5 of Set 8 | guajara-mirim
# City not found. Skipping...
# Processing Record 6 of Set 8 | harper
# Processing Record 7 of Set 8 | hailar
# Processing Record 8 of Set 8 | muramvya
# Processing Record 9 of Set 8 | cabo san lucas
# Processing Record 10 of Set 8 | takoradi
# Processing Record 11 of Set 8 | camacha
# Processing Record 12 of Set 8 | shakawe
# Processing Record 13 of Set 8 | ouadda
# Processing Record 14 of Set 8 | acarau
# Processing Record 15 of Set 8 | kawalu
# Processing Record 16 of Set 8 | matara
# Processing Record 17 of Set 8 | bundaberg
# Processing Record 18 of Set 8 | kichera
# Processing Record 19 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 8 | zuidhorn
# Processing Record 21 of Set 8 | semme
# Processing Record 22 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 8 | hithadhoo
# Processing Record 24 of Set 8 | broome
# Processing Record 25 of Set 8 | suntar
# Processing Record 26 of Set 8 | mantua
# Processing Record 27 of Set 8 | ranong
# Processing Record 28 of Set 8 | portland
# Processing Record 29 of Set 8 | beidao
# Processing Record 30 of Set 8 | cockburn town
# Processing Record 31 of Set 8 | krasnoselkup
# Processing Record 32 of Set 8 | talnakh
# Processing Record 33 of Set 8 | inhambane
# Processing Record 34 of Set 8 | faanui
# Processing Record 35 of Set 8 | bertoua
# Processing Record 36 of Set 8 | uenohara
# Processing Record 37 of Set 8 | aketi
# Processing Record 38 of Set 8 | barkly west
# Processing Record 39 of Set 8 | bilgoraj
# Processing Record 40 of Set 8 | roebourne
# Processing Record 41 of Set 8 | nanning
# Processing Record 42 of Set 8 | malakal
# Processing Record 43 of Set 8 | saint anthony
# Processing Record 44 of Set 8 | alyangula
# Processing Record 45 of Set 8 | pevek
# Processing Record 46 of Set 8 | silale
# Processing Record 47 of Set 8 | lakes entrance
# Processing Record 48 of Set 8 | zruc nad sazavou
# Processing Record 49 of Set 8 | kaitangata
# Processing Record 0 of Set 9 | clinton
# Processing Record 1 of Set 9 | palmer
# Processing Record 2 of Set 9 | kutum
# Processing Record 3 of Set 9 | rocha
# Processing Record 4 of Set 9 | eregli
# Processing Record 5 of Set 9 | bontang
# Processing Record 6 of Set 9 | bonavista
# Processing Record 7 of Set 9 | novoilinsk
# Processing Record 8 of Set 9 | klaksvik
# Processing Record 9 of Set 9 | cayenne
# Processing Record 10 of Set 9 | sandakan
# Processing Record 11 of Set 9 | fortuna
# Processing Record 12 of Set 9 | salalah
# Processing Record 13 of Set 9 | pahrump
# Processing Record 14 of Set 9 | tabuk
# Processing Record 15 of Set 9 | grindavik
# Processing Record 16 of Set 9 | canutama
# Processing Record 17 of Set 9 | rabo de peixe
# Processing Record 18 of Set 9 | amahai
# Processing Record 19 of Set 9 | bedford
# Processing Record 20 of Set 9 | muzhi
# Processing Record 21 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 22 of Set 9 | necochea
# Processing Record 23 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 9 | yantal
# Processing Record 25 of Set 9 | kjollefjord
# Processing Record 26 of Set 9 | roma
# Processing Record 27 of Set 9 | coquimbo
# Processing Record 28 of Set 9 | nyurba
# Processing Record 29 of Set 9 | altamont
# Processing Record 30 of Set 9 | ixtapa
# Processing Record 31 of Set 9 | college station
# Processing Record 32 of Set 9 | mandera
# Processing Record 33 of Set 9 | doka
# Processing Record 34 of Set 9 | balikpapan
# Processing Record 35 of Set 9 | mana
# Processing Record 36 of Set 9 | burias
# Processing Record 37 of Set 9 | padang
# Processing Record 38 of Set 9 | hasaki
# Processing Record 39 of Set 9 | galle
# Processing Record 40 of Set 9 | fulton
# Processing Record 41 of Set 9 | uhlove
# Processing Record 42 of Set 9 | arman
# Processing Record 43 of Set 9 | kendari
# Processing Record 44 of Set 9 | moramanga
# Processing Record 45 of Set 9 | ust-kuyga
# Processing Record 46 of Set 9 | hofn
# Processing Record 47 of Set 9 | wanaka
# Processing Record 48 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 49 of Set 9 | panguna
# Processing Record 0 of Set 10 | general pico
# Processing Record 1 of Set 10 | duz
# City not found. Skipping...
# Processing Record 2 of Set 10 | rio grande
# Processing Record 3 of Set 10 | puerto carreno
# Processing Record 4 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 5 of Set 10 | bo phloi
# Processing Record 6 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 10 | duliby
# Processing Record 8 of Set 10 | mossendjo
# Processing Record 9 of Set 10 | bage
# Processing Record 10 of Set 10 | caravelas
# Processing Record 11 of Set 10 | cardross
# Processing Record 12 of Set 10 | pingyin
# Processing Record 13 of Set 10 | atambua
# Processing Record 14 of Set 10 | hilantagaan
# Processing Record 15 of Set 10 | bodden town
# Processing Record 16 of Set 10 | mangai
# Processing Record 17 of Set 10 | honningsvag
# Processing Record 18 of Set 10 | olafsvik
# Processing Record 19 of Set 10 | soe
# Processing Record 20 of Set 10 | tzaneen
# Processing Record 21 of Set 10 | shu
# Processing Record 22 of Set 10 | bac lieu
# Processing Record 23 of Set 10 | tahe
# Processing Record 24 of Set 10 | tanjung morawa
# City not found. Skipping...
# Processing Record 25 of Set 10 | wanning
# Processing Record 26 of Set 10 | goure
# Processing Record 27 of Set 10 | jubayl
# City not found. Skipping...
# Processing Record 28 of Set 10 | dhidhdhoo
# Processing Record 29 of Set 10 | namibe
# Processing Record 30 of Set 10 | mareeba
# Processing Record 31 of Set 10 | bouar
# Processing Record 32 of Set 10 | pingliang
# Processing Record 33 of Set 10 | mogocha
# Processing Record 34 of Set 10 | coahuayana
# Processing Record 35 of Set 10 | gouyave
# Processing Record 36 of Set 10 | khasan
# Processing Record 37 of Set 10 | mildura
# Processing Record 38 of Set 10 | udachnyy
# Processing Record 39 of Set 10 | itambacuri
# Processing Record 40 of Set 10 | shirokiy
# Processing Record 41 of Set 10 | kodinsk
# Processing Record 42 of Set 10 | mehamn
# Processing Record 43 of Set 10 | alofi
# Processing Record 44 of Set 10 | dudinka
# Processing Record 45 of Set 10 | serebryansk
# Processing Record 46 of Set 10 | maragogi
# Processing Record 47 of Set 10 | naila
# Processing Record 48 of Set 10 | nadadores
# Processing Record 49 of Set 10 | san ramon de la nueva oran
# Processing Record 0 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 1 of Set 11 | sao joao da barra
# Processing Record 2 of Set 11 | tala
# Processing Record 3 of Set 11 | shubarkuduk
# Processing Record 4 of Set 11 | general roca
# Processing Record 5 of Set 11 | atar
# Processing Record 6 of Set 11 | orzhytsya
# Processing Record 7 of Set 11 | kourou
# Processing Record 8 of Set 11 | shingu
# Processing Record 9 of Set 11 | tairua
# Processing Record 10 of Set 11 | sheregesh
# Processing Record 11 of Set 11 | tarbes
# Processing Record 12 of Set 11 | belaya gora
# Processing Record 13 of Set 11 | borogontsy
# Processing Record 14 of Set 11 | cap malheureux
# Processing Record 15 of Set 11 | auki
# Processing Record 16 of Set 11 | vanavara
# Processing Record 17 of Set 11 | saint-ambroise
# Processing Record 18 of Set 11 | rawicz
# Processing Record 19 of Set 11 | dali
# Processing Record 20 of Set 11 | tarut
# Processing Record 21 of Set 11 | todos santos
# Processing Record 22 of Set 11 | eskasem
# City not found. Skipping...
# Processing Record 23 of Set 11 | jibuti
# Processing Record 24 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 11 | okhotsk
# Processing Record 26 of Set 11 | selikhino
# Processing Record 27 of Set 11 | coos bay
# Processing Record 28 of Set 11 | coaticook
# Processing Record 29 of Set 11 | bataipora
# Processing Record 30 of Set 11 | tucurui
# Processing Record 31 of Set 11 | kathu
# Processing Record 32 of Set 11 | jiuquan
# Processing Record 33 of Set 11 | vila
# Processing Record 34 of Set 11 | na wa
# Processing Record 35 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 11 | sinnamary
# Processing Record 37 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 11 | makakilo city
# Processing Record 39 of Set 11 | businga
# Processing Record 40 of Set 11 | bandarbeyla
# Processing Record 41 of Set 11 | blagoyevo
# Processing Record 42 of Set 11 | tikhvin
# Processing Record 43 of Set 11 | ugoofaaru
# Processing Record 44 of Set 11 | chernyshevskiy
# Processing Record 45 of Set 11 | vallenar
# Processing Record 46 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 47 of Set 11 | gunjur
# Processing Record 48 of Set 11 | uchiza
# Processing Record 49 of Set 11 | bathsheba
# Processing Record 0 of Set 12 | zeya
# Processing Record 1 of Set 12 | ler
# Processing Record 2 of Set 12 | medford
# Processing Record 3 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 12 | raudeberg
# Processing Record 5 of Set 12 | siocon
# Processing Record 6 of Set 12 | noumea
# Processing Record 7 of Set 12 | caldas novas
# Processing Record 8 of Set 12 | outjo
# Processing Record 9 of Set 12 | areosa
# Processing Record 10 of Set 12 | sabang
# Processing Record 11 of Set 12 | hami
# Processing Record 12 of Set 12 | sambava
# Processing Record 13 of Set 12 | kuusamo
# Processing Record 14 of Set 12 | margate
# Processing Record 15 of Set 12 | half moon bay
# Processing Record 16 of Set 12 | takaungu
# Processing Record 17 of Set 12 | sao gabriel da cachoeira
# Processing Record 18 of Set 12 | antalaha
# Processing Record 19 of Set 12 | saint-denis
# Processing Record 20 of Set 12 | camana
# Processing Record 21 of Set 12 | port macquarie
# Processing Record 22 of Set 12 | navolato
# Processing Record 23 of Set 12 | simplicio mendes
# Processing Record 24 of Set 12 | jiwani
# Processing Record 25 of Set 12 | soyo
# Processing Record 26 of Set 12 | aripuana
# Processing Record 27 of Set 12 | ati
# Processing Record 28 of Set 12 | mitsamiouli
# Processing Record 29 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 12 | henties bay
# Processing Record 31 of Set 12 | puerto penasco
# Processing Record 32 of Set 12 | abomsa
# Processing Record 33 of Set 12 | fare
# Processing Record 34 of Set 12 | sao mateus do sul
# Processing Record 35 of Set 12 | bhilwara
# Processing Record 36 of Set 12 | maningrida
# Processing Record 37 of Set 12 | nhulunbuy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          527
# Lat           527
# Lng           527
# Max Temp      527
# Humidity      527
# Cloudiness    527
# Wind Speed    527
# Country       527
# Date          527
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      rikitea -23.1203 -134.9692     22.93        90         100        7.52
# 1        bluff -46.6000  168.3333     15.44        70           0        5.48
# 2  yellowknife  62.4560 -114.3525     -2.71        68         100        2.57
# 3       aykhal  66.0000  111.5000     -7.36        88          96        7.45
# 4         chuy -33.6971  -53.4616     13.31        71           5        3.95
#
#   Country        Date
# 0      PF  1681435714
# 1      NZ  1681435714
# 2      CA  1681435497
# 3      RU  1681435714
# 4      UY  1681435714

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            rikitea -23.1203 -134.9692     22.93        90         100
# 1              bluff -46.6000  168.3333     15.44        70           0
# 2        yellowknife  62.4560 -114.3525     -2.71        68         100
# 3             aykhal  66.0000  111.5000     -7.36        88          96
# 4               chuy -33.6971  -53.4616     13.31        71           5
#
#          Wind Speed Country        Date
# City_ID
# 0              7.52      PF  1681435714
# 1              5.48      NZ  1681435714
# 2              2.57      CA  1681435497
# 3              7.45      RU  1681435714
# 4              3.95      UY  1681435714

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot('Lat','Max Temp',kind='scatter')
# Incorporate the other graph properties
max_date = pd.to_datetime(city_data_df['Date'].max(), unit='s').date()
plt.title("Latitude vs Max Temperature ("+str(max_date)+")")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (C)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
city_data_df.plot('Lat','Humidity',kind='scatter')

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity ("+str(max_date)+")")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot('Lat','Cloudiness',kind='scatter')

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness ("+str(max_date)+")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot('Lat','Wind Speed',kind='scatter')

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed ("+str(max_date)+")")
plt.xlabel("city Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def draw_regression_line(x_values,y_values,x,y):
    slope, intercept, rval, pval, std_err = linregress(x_values,y_values)
    print(f"The r-value is: {rval**2}")
    fit = slope * x_values  + intercept
    line_eq=f"y = {round(slope,2)}x + {round(intercept,2)}"
    plt.scatter(x_values,y_values)
    plt.annotate(line_eq,(x,y),fontsize=15,color="red")
    plt.xlabel("Latitude")
    return plt.plot(x_values,fit,'-', color='r')

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0,:]
# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        yellowknife  62.4560 -114.3525     -2.71        68         100
# 3             aykhal  66.0000  111.5000     -7.36        88          96
# 8         lavrentiya  65.5833 -171.0000    -13.81        72           5
# 9               adre  13.4667   22.2000     24.49        21           0
# 10        port hardy  50.6996 -127.4199      8.10        71          75
#
#          Wind Speed Country        Date
# City_ID
# 2              2.57      CA  1681435497
# 3              7.45      RU  1681435714
# 8              4.14      RU  1681435715
# 9              3.40      TD  1681435716
# 10             2.06      CA  1681435716

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0,:]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             rikitea -23.1203 -134.9692     22.93        90         100
# 1               bluff -46.6000  168.3333     15.44        70           0
# 4                chuy -33.6971  -53.4616     13.31        71           5
# 5        punta arenas -53.1500  -70.9167      1.06        86           0
# 6           busselton -33.6500  115.3333     14.67        47          89
#
#          Wind Speed Country        Date
# City_ID
# 0              7.52      PF  1681435714
# 1              5.48      NZ  1681435714
# 4              3.95      UY  1681435714
# 5              2.57      CL  1681435265
# 6              6.25      AU  1681435715

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
draw_regression_line(northern_hemi_df['Lat'],northern_hemi_df["Max Temp"],10,-20)
plt.ylabel("Max Temperature")
plt.show()
# Out:
# The r-value is: 0.7883377726950741

# %%
# Linear regression on Southern Hemisphere
draw_regression_line(southern_hemi_df['Lat'],southern_hemi_df["Max Temp"],-55,30)
plt.ylabel("Max Temperature")
plt.show()
# Out:
# The r-value is: 0.47651253644919617

# %% [markdown]
# **Discussion about the linear relationship:** Temperature variations in the northern hemishpere have a higher linear relationship with latititudes (74.62%) as compared to the relationship between temperatures and latitude in the southern hemisphere (42.42%).

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
draw_regression_line(northern_hemi_df['Lat'],northern_hemi_df["Humidity"],40,0)
plt.ylabel("Humidity")
plt.show()
# Out:
# The r-value is: 0.02403146041181447

# %%
# Southern Hemisphere
draw_regression_line(southern_hemi_df['Lat'],southern_hemi_df["Humidity"],-50,20)
plt.ylabel("Humidity")
plt.show()
# Out:
# The r-value is: 0.13611357888026052

# %% [markdown]
# **Discussion about the linear relationship:** Only 12.21% of variations in humidity in the northern hemisphere are accounted for by the change in latitude while only 8.58% of hunidity variations in the southern hemisphere and be accounted for changes in latitude. Small linear relationship between humidity and latitude in both the hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
#Northern Hemisphere
draw_regression_line(northern_hemi_df['Lat'],northern_hemi_df["Cloudiness"],40,55)
plt.ylabel("Cloudiness")
plt.show()
# Out:
# The r-value is: 0.0036716844457742003

# %%
#Southern Hemisphere
draw_regression_line(southern_hemi_df['Lat'],southern_hemi_df["Cloudiness"],-52,60)
plt.ylabel("Cloudiness")
plt.show()
# Out:
# The r-value is: 0.1525575865511948

# %% [markdown]
# **Discussion about the linear relationship:** Only 4.42% of cloudiness variations can be accounted for by changes in the northern hemishpere lattitudes, while onlt 13% of cloudiness variations can be accounted for by the changes in a Southern hemisphere latitude changes, very small linear relationship between cloudiness and latitude in both the hemishperes.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
draw_regression_line(northern_hemi_df['Lat'],northern_hemi_df["Wind Speed"],10,12)
plt.ylabel("Wind Speed")
plt.show()
# Out:
# The r-value is: 0.03977785052916939

# %%
# Southern Hemisphere
draw_regression_line(southern_hemi_df['Lat'],southern_hemi_df["Wind Speed"],-50,9)
plt.ylabel("Wind Speed")
plt.show()
# Out:
# The r-value is: 0.08079671808809896

# %% [markdown]
# **Discussion about the linear relationship:** Only 0.96% of variations in wind speed is accounted for with change in the northern hemisphere latitdude and 7.73% of variations in wind speed is accounted for changes in the southern hemisphere latitude, very low linear relationship between wind speed and latitude in both the hemispheres.
